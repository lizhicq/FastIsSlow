# %%
from mutagen.flac import FLAC
from mutagen.easyid3 import EasyID3
import os

# %%
path = r"/Users/lizhicq/Drive/Music/流行乐"
for root, dirs, files in os.walk(path):
    for file in files:
        try:
            filepath = os.path.join(root, file)
            
            if file.endswith('.flac'):
                audio = FLAC(filepath)
                file = file[:-5]
            
            elif file.endswith('.mp3'):
                audio = EasyID3(filepath)
                file = file[:-4]
            
            if audio['title'] != '':
                audio['title'] = "" # clear title
                audio['comment'] = "" # clear comment
                audio.save()
                print(audio)
        except:
            pass
# Out:
# {'date': ['2010'], 'artist': ['Waka Waka (This Time For Africa) - Shakira con Freshlyground'], 'genre': ['Pop-Rock'], 'last_played': ['2010-06-11 16:28:03'], 'album': ['Listen Up The official 2010 fifa world cup album'], 'play_counter': ['1'], 'tracknumber': ['02'], 'title': [''], 'first_played': ['2010-06-11 16:28:03'], 'comment': ['']}
# {'artist': ['周杰伦'], 'album': ['范特西PLUS'], 'title': [''], 'comment': ['']}
# {'date': ['2004'], 'artist': ['杨千嬅'], 'genre': ['Pop'], 'album': ['电光幻影'], 'tracknumber': ['3'], 'discid': ['9611560B'], 'title': [''], 'tracktotal': ['10'], 'comment': ['']}
# {'artist': ['林俊杰'], 'album': ['JJ陆'], 'title': [''], 'comment': ['']}
# {'artist': ['苏打绿'], 'album': ['小宇宙'], 'title': [''], 'comment': ['']}
# {'artist': ['蔡琴'], 'album': ['惠威试音天碟Ⅱ'], 'title': [''], 'comment': ['']}
# {'artist': ['费玉清'], 'album': ['天之大'], 'title': [''], 'comment': ['']}
# {'artist': ['Ed Sheeran'], 'album': ['÷ (Deluxe)'], 'title': [''], 'comment': ['']}
# {'artist': ['李翊君'], 'album': ['风云 电视剧原声带'], 'title': [''], 'comment': ['']}
# {'artist': ['苏打绿'], 'album': ['无与伦比的美丽'], 'title': [''], 'comment': ['']}
# {'artist': ['莫文蔚'], 'album': ['滾石香港十年精選'], 'title': [''], 'comment': ['']}
# {'artist': ['彭佳慧'], 'album': ['敲敲我的头'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['王菲'], 'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'artist': ['赵雷'], 'genre': ['Pop'], 'album': ['赵小雷'], 'title': [''], 'tracktotal': ['10'], 'encoder': ['Lavf57.41.100'], 'comment': ['']}
# {'date': ['2007-12-14'], 'artist': ['Andy Williams'], 'album': ['The Essential Andy Williams'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['唱游'], 'title': [''], 'comment': ['']}
# {'artist': ['李荣浩'], 'album': ['耳朵'], 'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'artist': ['周杰伦'], 'album': ['跨时代'], 'title': [''], 'comment': ['']}
# {'artist': ['霍建华'], 'album': ['新笑傲江湖 电视剧原声带'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['传奇'], 'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'artist': ['郭静'], 'album': ['在树上唱歌'], 'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'artist': ['林俊杰'], 'album': ['第二天堂'], 'title': [''], 'comment': ['']}
# {'artist': ['王杰'], 'album': ['故事的角色'], 'title': [''], 'comment': ['']}
# {'artist': ['苏打绿'], 'album': ['秋：故事'], 'title': [''], 'comment': ['']}
# {'artist': ['郭静'], 'album': ['在树上唱歌'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'title': [''], 'comment': ['']}
# {'artist': ['凤凰传奇'], 'album': ['我从草原来'], 'title': [''], 'comment': ['']}
# {'artist': ['郑钧'], 'album': ['赤裸裸'], 'title': [''], 'comment': ['']}
# {'artist': ['陈百强'], 'album': ['偏偏喜欢你'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['菲靡靡之音'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['无问西东'], 'title': [''], 'comment': ['']}
# {'artist': ['李行亮'], 'album': ['愿得一人心'], 'title': [''], 'comment': ['']}
# {'artist': ['王杰'], 'album': ['一场游戏一场梦'], 'title': [''], 'comment': ['']}
# {'artist': ['辛晓琪'], 'copyright': ['QQ音乐'], 'album': ['辛晓琪精选集A'], 'title': [''], 'comment': ['']}
# {'artist': ['赵鹏'], 'album': ['低音王朝I 你的眼神'], 'title': [''], 'comment': ['']}
# {'artist': ['崔健'], 'album': ['一无所有'], 'title': [''], 'comment': ['']}
# {'date': ['2018-10-02'], 'time_reference': ['68727'], 'encoded_by': ['REAPER'], 'title': [''], 'encoder': ['Lavf57.56.100'], 'comment': ['']}
# {'artist': ['[来自：www.ape520.com]许嵩'], 'genre': ['[来自：www.ape520.com]'], 'album': ['[来自：www.ape520.com]'], 'title': [''], 'comment': ['']}
# {'artist': ['鞠婧祎'], 'album': ['落花成泥'], 'title': [''], 'encoder': ['Lavf57.56.100'], 'comment': ['']}
# {'artist': ['陈奕迅'], 'album': ['认了吧'], 'title': [''], 'comment': ['']}
# {'artist': ['王力宏'], 'album': ['盖世英雄'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['勇气'], 'title': [''], 'comment': ['']}
# {'date': ['2012'], 'artist': ['欧美金唱片'], 'genre': ['流行歌曲演唱'], 'album': ['California Style Gourmet Collection'], 'tracknumber': ['18'], 'title': [''], 'comment': ['']}
# {'artist': ['BØRNS'], 'album': ['Blue Madonna'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['崇拜'], 'title': [''], 'comment': ['']}
# {'artist': ['(2006)林俊杰'], 'replaygain_track_gain': ['-9.76 dB'], 'replaygain_track_peak': ['1'], 'title': [''], 'comment': ['']}
# {'artist': ['张靓颖'], 'album': ['梦想的声音第二季 第5期'], 'title': [''], 'comment': ['']}
# {'encoder': ['Lavf56.40.101'], 'title': [''], 'comment': ['']}
# {'artist': ['(2005)林俊杰、金莎'], 'replaygain_track_gain': ['-9.6 dB'], 'replaygain_track_peak': ['0.988586'], 'title': [''], 'comment': ['']}
# {'date': ['2014-11-17'], 'artist': ['赵雷'], 'album': ['吉姆餐厅'], 'title': [''], 'comment': ['']}
# {'date': ['2010-01-28'], 'artist': ['孙燕姿'], 'album': ['My Story, Your Song 经典全纪录 (2010香港特别版) Cd2'], 'title': [''], 'comment': ['']}
# {'artist': ['李荣浩'], 'album': ['模特'], 'title': [''], 'comment': ['']}
# {'artist': ['李翊君'], 'album': ['誓言谎言'], 'title': [''], 'comment': ['']}
# {'artist': ['周杰伦'], 'album': ['依然范特西'], 'title': [''], 'comment': ['']}
# {'artist': ['(1996)屠洪纲'], 'album artist': ['Various Aritsts'], 'album': ['雕刻时光(中国歌曲排行榜1995)'], 'replaygain_track_gain': ['-3.3 dB'], 'replaygain_track_peak': ['0.935425'], 'tracknumber': ['3'], 'title': [''], 'comment': ['']}
# {'artist': ['费玉清'], 'album': ['天之大'], 'title': [''], 'comment': ['']}
# {'artist': ['毛泽少'], 'album': ['龙珠传奇 电视剧原声带'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['亲亲'], 'title': [''], 'comment': ['']}
# {'artist': ['陈奕迅'], 'album': ['认了吧'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['王菲'], 'title': [''], 'comment': ['']}
# {'artist': ['李翊君'], 'album': ['勇敢的爱'], 'title': [''], 'comment': ['']}
# {'artist': ['霍尊'], 'album': ['寂寞空庭春欲晚 电视剧原声带'], 'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'artist': ['林俊杰'], 'album': ['第二天堂'], 'title': [''], 'comment': ['']}
# {'artist': ['陆虎'], 'album': ['雪落下的声音'], 'title': [''], 'comment': ['']}
# {'artist': ['Lana Del Rey'], 'album': ['Born To Die (Deluxe Version)'], 'title': [''], 'comment': ['']}
# {'artist': ['王力宏'], 'album': ['心中的日月'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['坚强的背后'], 'title': [''], 'comment': ['']}
# {'artist': ['赵雷'], 'album': ['赵小雷'], 'title': [''], 'comment': ['']}
# {'date': ['2016-12-2'], 'time_reference': ['92903'], 'encoded_by': ['Pro Tools'], 'originator_reference': ['0ceujtDIFIjaaaGk'], 'title': [''], 'encoder': ['Lavf57.41.100'], 'comment': ['']}
# {'artist': ['黄小琥'], 'album': ['简单不简单'], 'title': [''], 'comment': ['']}
# {'artist': ['毛泽少'], 'album': ['龙珠传奇 电视剧原声带'], 'title': [''], 'comment': ['']}
# {'artist': ['Lana Del Rey'], 'album': ['Born To Die'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['匆匆那年'], 'title': [''], 'comment': ['']}
# {'artist': ['田馥甄'], 'album': ['To My Love 影音馆'], 'title': [''], 'comment': ['']}
# {'artist': ['陈奕迅'], 'album': ['认了吧'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['亲亲'], 'title': [''], 'comment': ['']}
# {'artist': ['Lana Del Rey'], 'album': ['Born To Die (Deluxe Version)'], 'title': [''], 'comment': ['']}
# {'artist': ['李健'], 'album': ['遥远的天空底下'], 'title': [''], 'comment': ['']}
# {'artist': ['郭静'], 'album': ['这一切还是迷人的'], 'title': [''], 'comment': ['']}
# {'artist': ['林俊杰'], 'copyright': ['QQ音乐'], 'album': ['她说'], 'title': [''], 'comment': ['']}
# {'artist': ['王菲'], 'album': ['寓言'], 'title': [''], 'comment': ['']}
# {'artist': ['郭静'], 'album': ['在树上唱歌'], 'title': [''], 'comment': ['']}
# {'artist': ['杨宗纬'], 'album': ['一次就好'], 'title': [''], 'comment': ['']}
# {'artist': ['张靓颖'], 'album': ['第七感'], 'title': [''], 'comment': ['']}
# {'artist': ['李圣杰'], 'copyright': ['QQ音乐'], 'album': ['孤鸾疗伤版'], 'title': [''], 'comment': ['']}
# {'artist': ['乌兰托娅'], 'album': ['我要去西藏'], 'title': [''], 'comment': ['']}
# {'artist': ['郭静'], 'album': ['下一个天亮'], 'title': [''], 'comment': ['']}
# {'artist': ['华语群星'], 'album': ['环球综艺秀'], 'title': [''], 'comment': ['']}
# {'artist': ['张靓颖'], 'album': ['女儿国'], 'title': [''], 'comment': ['']}
# {'artist': ['容祖儿'], 'album': ['小小'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['爱久见人心'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['理性与感性 作品音乐会'], 'title': [''], 'comment': ['']}
# {'artist': ['鞠婧祎'], 'album': ['叹云兮'], 'title': [''], 'comment': ['']}
# {'artist': ['Shakira'], 'album': ['Zootopia (Original Motion Picture Soundtrack)'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['燕尾蝶'], 'title': [''], 'comment': ['']}
# {'artist': ['梁静茹'], 'album': ['崇拜'], 'title': [''], 'comment': ['']}
# {'artist': ['孙燕姿'], 'album': ['风筝'], 'title': [''], 'comment': ['']}
# {'artist': ['陈奕迅'], 'album': ['Stranger Under My Skin'], 'title': [''], 'comment': ['']}
# {'artist': ['李荣浩'], 'album': ['有理想'], 'title': [''], 'comment': ['']}
# {'artist': ['张靓颖'], 'album': ['我相信'], 'title': [''], 'comment': ['']}
# {'artist': ['周杰伦'], 'album': ['我很忙'], 'title': [''], 'comment': ['']}
# {'artist': ['大壮'], 'album': ['差一步'], 'title': [''], 'comment': ['']}
# {'artist': ['G.E.M. 邓紫棋'], 'album': ['王牌对王牌第三季 第8期'], 'title': [''], 'comment': ['']}
# {'artist': ['孙燕姿'], 'album': ['未完成'], 'title': [''], 'comment': ['']}
# {'artist': ['陈慧娴'], 'album': ['永远是你的朋友'], 'title': [''], 'comment': ['']}
