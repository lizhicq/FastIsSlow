# %%
from mutagen.flac import FLAC
from mutagen.easyid3 import EasyID3
import os

# %%
path = r"/Users/lizhicq/Drive/Music/流行乐"
for root, dirs, files in os.walk(path):
    for file in files:
        try:
            filepath = os.path.join(root, file)
            if file.endswith('.flac'):
                audio = FLAC(filepath)
                file = file[:-5]
            elif file.endswith('.mp3'):
                audio = EasyID3(filepath)
                file = file[:-4]
            audio['title'] = "" # clear title
            audio['comment'] = "" # clear comment
            audio.save()
            print(audio)
        except:
            pass
# Out:
# {'play_counter': ['1'], 'last_played': ['2010-06-11 16:28:03'], 'genre': ['Pop-Rock'], 'album': ['Listen Up The official 2010 fifa world cup album'], 'comment': [''], 'date': ['2010'], 'tracknumber': ['02'], 'title': [''], 'artist': ['Waka Waka (This Time For Africa) - Shakira con Freshlyground'], 'first_played': ['2010-06-11 16:28:03']}
# {'title': [''], 'album': ['范特西PLUS'], 'comment': [''], 'artist': ['周杰伦']}
# {'genre': ['Pop'], 'album': ['电光幻影'], 'comment': [''], 'date': ['2004'], 'tracknumber': ['3'], 'title': [''], 'artist': ['杨千嬅'], 'tracktotal': ['10'], 'discid': ['9611560B']}
# {'album': ['JJ陆'], 'title': [''], 'artist': ['林俊杰'], 'comment': ['']}
# {'title': [''], 'album': ['小宇宙'], 'comment': [''], 'artist': ['苏打绿']}
# {'title': [''], 'album': ['惠威试音天碟Ⅱ'], 'comment': [''], 'artist': ['蔡琴']}
# {'title': [''], 'album': ['天之大'], 'comment': [''], 'artist': ['费玉清']}
# {'title': [''], 'album': ['÷ (Deluxe)'], 'comment': [''], 'artist': ['Ed Sheeran']}
# {'title': [''], 'album': ['风云 电视剧原声带'], 'comment': [''], 'artist': ['李翊君']}
# {'title': [''], 'album': ['无与伦比的美丽'], 'comment': [''], 'artist': ['苏打绿']}
# {'album': ['滾石香港十年精選'], 'title': [''], 'artist': ['莫文蔚'], 'comment': ['']}
# {'title': [''], 'album': ['敲敲我的头'], 'comment': [''], 'artist': ['彭佳慧']}
# {'title': [''], 'album': ['王菲'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'comment': ['']}
# {'genre': ['Pop'], 'album': ['赵小雷'], 'comment': [''], 'encoder': ['Lavf57.41.100'], 'title': [''], 'artist': ['赵雷'], 'tracktotal': ['10']}
# {'album': ['The Essential Andy Williams'], 'comment': [''], 'date': ['2007-12-14'], 'title': [''], 'artist': ['Andy Williams']}
# {'title': [''], 'album': ['唱游'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'album': ['耳朵'], 'comment': [''], 'artist': ['李荣浩']}
# {'title': [''], 'comment': ['']}
# {'title': [''], 'comment': ['']}
# {'title': [''], 'album': ['跨时代'], 'comment': [''], 'artist': ['周杰伦']}
# {'title': [''], 'album': ['新笑傲江湖 电视剧原声带'], 'comment': [''], 'artist': ['霍建华']}
# {'title': [''], 'album': ['传奇'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'comment': ['']}
# {'title': [''], 'album': ['在树上唱歌'], 'comment': [''], 'artist': ['郭静']}
# {'title': [''], 'comment': ['']}
# {'title': [''], 'album': ['第二天堂'], 'comment': [''], 'artist': ['林俊杰']}
# {'title': [''], 'album': ['故事的角色'], 'comment': [''], 'artist': ['王杰']}
# {'title': [''], 'album': ['秋：故事'], 'comment': [''], 'artist': ['苏打绿']}
# {'title': [''], 'album': ['在树上唱歌'], 'comment': [''], 'artist': ['郭静']}
# {'title': [''], 'artist': ['梁静茹'], 'comment': ['']}
# {'title': [''], 'album': ['我从草原来'], 'comment': [''], 'artist': ['凤凰传奇']}
# {'title': [''], 'album': ['赤裸裸'], 'comment': [''], 'artist': ['郑钧']}
# {'title': [''], 'album': ['偏偏喜欢你'], 'comment': [''], 'artist': ['陈百强']}
# {'title': [''], 'album': ['菲靡靡之音'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'album': ['无问西东'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'album': ['愿得一人心'], 'comment': [''], 'artist': ['李行亮']}
# {'title': [''], 'album': ['一场游戏一场梦'], 'comment': [''], 'artist': ['王杰']}
# {'album': ['辛晓琪精选集A'], 'comment': [''], 'title': [''], 'artist': ['辛晓琪'], 'copyright': ['QQ音乐']}
# {'title': [''], 'album': ['低音王朝I 你的眼神'], 'comment': [''], 'artist': ['赵鹏']}
# {'title': [''], 'album': ['一无所有'], 'comment': [''], 'artist': ['崔健']}
# {'time_reference': ['68727'], 'comment': [''], 'date': ['2018-10-02'], 'encoder': ['Lavf57.56.100'], 'title': [''], 'encoded_by': ['REAPER']}
# {'genre': ['[来自：www.ape520.com]'], 'album': ['[来自：www.ape520.com]'], 'comment': [''], 'title': [''], 'artist': ['[来自：www.ape520.com]许嵩']}
# {'album': ['落花成泥'], 'comment': [''], 'encoder': ['Lavf57.56.100'], 'title': [''], 'artist': ['鞠婧祎']}
# {'title': [''], 'album': ['认了吧'], 'comment': [''], 'artist': ['陈奕迅']}
# {'title': [''], 'album': ['盖世英雄'], 'comment': [''], 'artist': ['王力宏']}
# {'title': [''], 'album': ['勇气'], 'comment': [''], 'artist': ['梁静茹']}
# {'genre': ['流行歌曲演唱'], 'album': ['California Style Gourmet Collection'], 'comment': [''], 'date': ['2012'], 'tracknumber': ['18'], 'title': [''], 'artist': ['欧美金唱片']}
# {'title': [''], 'album': ['Blue Madonna'], 'comment': [''], 'artist': ['BØRNS']}
# {'title': [''], 'album': ['崇拜'], 'comment': [''], 'artist': ['梁静茹']}
# {'comment': [''], 'title': [''], 'artist': ['(2006)林俊杰'], 'replaygain_track_gain': ['-9.76 dB'], 'replaygain_track_peak': ['1']}
# {'title': [''], 'album': ['梦想的声音第二季 第5期'], 'comment': [''], 'artist': ['张靓颖']}
# {'encoder': ['Lavf56.40.101'], 'title': [''], 'comment': ['']}
# {'comment': [''], 'title': [''], 'artist': ['(2005)林俊杰、金莎'], 'replaygain_track_gain': ['-9.6 dB'], 'replaygain_track_peak': ['0.988586']}
# {'album': ['吉姆餐厅'], 'comment': [''], 'date': ['2014-11-17'], 'title': [''], 'artist': ['赵雷']}
# {'album': ['My Story, Your Song 经典全纪录 (2010香港特别版) Cd2'], 'comment': [''], 'date': ['2010-01-28'], 'title': [''], 'artist': ['孙燕姿']}
# {'title': [''], 'album': ['模特'], 'comment': [''], 'artist': ['李荣浩']}
# {'title': [''], 'album': ['誓言谎言'], 'comment': [''], 'artist': ['李翊君']}
# {'title': [''], 'album': ['依然范特西'], 'comment': [''], 'artist': ['周杰伦']}
# {'album': ['雕刻时光(中国歌曲排行榜1995)'], 'comment': [''], 'tracknumber': ['3'], 'title': [''], 'artist': ['(1996)屠洪纲'], 'replaygain_track_gain': ['-3.3 dB'], 'replaygain_track_peak': ['0.935425'], 'album artist': ['Various Aritsts']}
# {'title': [''], 'album': ['天之大'], 'comment': [''], 'artist': ['费玉清']}
# {'title': [''], 'album': ['龙珠传奇 电视剧原声带'], 'comment': [''], 'artist': ['毛泽少']}
# {'title': [''], 'album': ['亲亲'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['认了吧'], 'comment': [''], 'artist': ['陈奕迅']}
# {'title': [''], 'album': ['王菲'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'album': ['勇敢的爱'], 'comment': [''], 'artist': ['李翊君']}
# {'title': [''], 'album': ['寂寞空庭春欲晚 电视剧原声带'], 'comment': [''], 'artist': ['霍尊']}
# {'title': [''], 'comment': ['']}
# {'title': [''], 'album': ['第二天堂'], 'comment': [''], 'artist': ['林俊杰']}
# {'title': [''], 'album': ['雪落下的声音'], 'comment': [''], 'artist': ['陆虎']}
# {'title': [''], 'album': ['Born To Die (Deluxe Version)'], 'comment': [''], 'artist': ['Lana Del Rey']}
# {'title': [''], 'album': ['心中的日月'], 'comment': [''], 'artist': ['王力宏']}
# {'title': [''], 'album': ['坚强的背后'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['赵小雷'], 'comment': [''], 'artist': ['赵雷']}
# {'time_reference': ['92903'], 'comment': [''], 'date': ['2016-12-2'], 'encoder': ['Lavf57.41.100'], 'title': [''], 'originator_reference': ['0ceujtDIFIjaaaGk'], 'encoded_by': ['Pro Tools']}
# {'title': [''], 'album': ['简单不简单'], 'comment': [''], 'artist': ['黄小琥']}
# {'title': [''], 'album': ['龙珠传奇 电视剧原声带'], 'comment': [''], 'artist': ['毛泽少']}
# {'title': [''], 'album': ['Born To Die'], 'comment': [''], 'artist': ['Lana Del Rey']}
# {'title': [''], 'album': ['匆匆那年'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'album': ['To My Love 影音馆'], 'comment': [''], 'artist': ['田馥甄']}
# {'title': [''], 'album': ['认了吧'], 'comment': [''], 'artist': ['陈奕迅']}
# {'title': [''], 'album': ['亲亲'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['Born To Die (Deluxe Version)'], 'comment': [''], 'artist': ['Lana Del Rey']}
# {'title': [''], 'album': ['遥远的天空底下'], 'comment': [''], 'artist': ['李健']}
# {'title': [''], 'album': ['这一切还是迷人的'], 'comment': [''], 'artist': ['郭静']}
# {'album': ['她说'], 'comment': [''], 'title': [''], 'artist': ['林俊杰'], 'copyright': ['QQ音乐']}
# {'title': [''], 'album': ['寓言'], 'comment': [''], 'artist': ['王菲']}
# {'title': [''], 'album': ['在树上唱歌'], 'comment': [''], 'artist': ['郭静']}
# {'title': [''], 'album': ['一次就好'], 'comment': [''], 'artist': ['杨宗纬']}
# {'title': [''], 'album': ['第七感'], 'comment': [''], 'artist': ['张靓颖']}
# {'album': ['孤鸾疗伤版'], 'comment': [''], 'title': [''], 'artist': ['李圣杰'], 'copyright': ['QQ音乐']}
# {'title': [''], 'album': ['我要去西藏'], 'comment': [''], 'artist': ['乌兰托娅']}
# {'title': [''], 'album': ['下一个天亮'], 'comment': [''], 'artist': ['郭静']}
# {'title': [''], 'album': ['环球综艺秀'], 'comment': [''], 'artist': ['华语群星']}
# {'title': [''], 'album': ['女儿国'], 'comment': [''], 'artist': ['张靓颖']}
# {'title': [''], 'album': ['小小'], 'comment': [''], 'artist': ['容祖儿']}
# {'title': [''], 'album': ['爱久见人心'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['理性与感性 作品音乐会'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['叹云兮'], 'comment': [''], 'artist': ['鞠婧祎']}
# {'title': [''], 'album': ['Zootopia (Original Motion Picture Soundtrack)'], 'comment': [''], 'artist': ['Shakira']}
# {'title': [''], 'album': ['燕尾蝶'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['崇拜'], 'comment': [''], 'artist': ['梁静茹']}
# {'title': [''], 'album': ['风筝'], 'comment': [''], 'artist': ['孙燕姿']}
# {'title': [''], 'album': ['Stranger Under My Skin'], 'comment': [''], 'artist': ['陈奕迅']}
# {'title': [''], 'album': ['有理想'], 'comment': [''], 'artist': ['李荣浩']}
# {'title': [''], 'album': ['我相信'], 'comment': [''], 'artist': ['张靓颖']}
# {'title': [''], 'album': ['我很忙'], 'comment': [''], 'artist': ['周杰伦']}
# {'title': [''], 'album': ['差一步'], 'comment': [''], 'artist': ['大壮']}
# {'title': [''], 'album': ['王牌对王牌第三季 第8期'], 'comment': [''], 'artist': ['G.E.M. 邓紫棋']}
# {'title': [''], 'album': ['未完成'], 'comment': [''], 'artist': ['孙燕姿']}
# {'title': [''], 'album': ['永远是你的朋友'], 'comment': [''], 'artist': ['陈慧娴']}

# %%
audio['title'] = ""
